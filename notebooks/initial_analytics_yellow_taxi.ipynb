# %% [markdown]
# # NYC Transportation Market Analysis

# %% [markdown]
# ## 1. Objective
#
# The goal of this notebook is to perform an initial exploratory data analysis (EDA) on the Yellow Taxi and High-Volume For-Hire Vehicle (HVFHV) datasets. We will use pandas to profile a sample of the data.
#
# This analysis will not be exhaustive but will focus on:
#
# 1. Schema Profiling: Understanding the columns, data types, and null values.
# 2. Data cleaning: Identifying "dirty data" (e.g., negative fares, 0-mile trips, outliers).
# 3. Conformance Strategy: Formulating the business logic required to successfully design the ETL

# %% [markdown]
# ## 2.Datasets
#
#     Yellow Taxi: yellow_tripdata_2024-{01, 02, 03}.parquet
#
#     FHVHV (Uber/Lyft etc.): fhvhv_tripdata_2024-{01, 02, 03}.parquet
#
#     Zone Lookup: taxi_zone_lookup.csv

# %% [markdown]
# ## 2. Setup: Imports, Settings, and File Paths

# %%
import networkx as nx
import pandas as pd

# %%
YELLOW_TAXI_PATH = '../data/raw/taxi/yellow_tripdata_2024-01.parquet'
ZONE_LOOKUP_PATH = '../data/raw/lookups/taxi_zone_lookup.csv'

# %% [markdown]
# ## 3. Data Loading
# Load the three datasets into memory.

# %%
yellow_df = pd.read_parquet(YELLOW_TAXI_PATH)
lookup_df = pd.read_csv(ZONE_LOOKUP_PATH)

# %%
yellow_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         17.7    1.0      0.5        0.00           0.0
# 1             1         10.0    3.5      0.5        3.75           0.0
# 2             1         23.3    3.5      0.5        3.00           0.0
# 3             1         10.0    3.5      0.5        2.00           0.0
# 4             1          7.9    3.5      0.5        3.20           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         22.70                   2.5          0.0
# 1                    1.0         18.75                   2.5          0.0
# 2                    1.0         31.30                   2.5          0.0
# 3                    1.0         17.00                   2.5          0.0
# 4                    1.0         16.10                   2.5          0.0

# %%
yellow_df.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2964624 entries, 0 to 2964623
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               2964624 non-null  int32
#  1   tpep_pickup_datetime   2964624 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  2964624 non-null  datetime64[us]
#  3   passenger_count        2824462 non-null  float64
#  4   trip_distance          2964624 non-null  float64
#  5   RatecodeID             2824462 non-null  float64
#  6   store_and_fwd_flag     2824462 non-null  object
#  7   PULocationID           2964624 non-null  int32
#  8   DOLocationID           2964624 non-null  int32
#  9   payment_type           2964624 non-null  int64
#  10  fare_amount            2964624 non-null  float64
#  11  extra                  2964624 non-null  float64
#  12  mta_tax                2964624 non-null  float64
#  13  tip_amount             2964624 non-null  float64
#  14  tolls_amount           2964624 non-null  float64
#  15  improvement_surcharge  2964624 non-null  float64
#  16  total_amount           2964624 non-null  float64
#  17  congestion_surcharge   2824462 non-null  float64
#  18  Airport_fee            2824462 non-null  float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# memory usage: 395.8+ MB

# %%
yellow_df['RatecodeID'].isna().sum()
# Out:
# np.int64(140162)

# %%
null_counts = yellow_df.isnull().sum()

columns_with_nulls = null_counts[null_counts > 0]

# %%
columns_with_nulls
# Out:
# passenger_count         140162
# RatecodeID              140162
# store_and_fwd_flag      140162
# congestion_surcharge    140162
# Airport_fee             140162
# dtype: int64

# %%
yellow_df.fillna({'RatecodeID': 99.0}, inplace=True)

# %%
yellow_df.fillna({'passenger_count': 0.0}, inplace=True)

# %%
yellow_df['RatecodeID'] = yellow_df['RatecodeID'].astype('int32')
yellow_df['passenger_count'] = yellow_df['passenger_count'].astype('int32')

yellow_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43                1
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36                1
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01                1
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56                1
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57                1
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36                0
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52                0
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00                0
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14                0
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30                0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.72           1                  N           186
# 1                 1.80           1                  N           140
# 2                 4.70           1                  N           236
# 3                 1.40           1                  N            79
# 4                 0.80           1                  N           211
# ...                ...         ...                ...           ...
# 2964619           3.18          99               None           107
# 2964620           4.00          99               None           114
# 2964621           3.33          99               None           211
# 2964622           3.06          99               None           107
# 2964623           8.10          99               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  79             2        17.70   1.00      0.5        0.00
# 1                 236             1        10.00   3.50      0.5        3.75
# 2                  79             1        23.30   3.50      0.5        3.00
# 3                 211             1        10.00   3.50      0.5        2.00
# 4                 148             1         7.90   3.50      0.5        3.20
# ...               ...           ...          ...    ...      ...         ...
# 2964619           263             0        15.77   0.00      0.5        2.00
# 2964620           236             0        18.40   1.00      0.5        2.34
# 2964621            25             0        19.97   0.00      0.5        0.00
# 2964622            13             0        23.88   0.00      0.5        5.58
# 2964623            75             0        32.40   7.75      0.5        7.29
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         22.70
# 1                0.00                    1.0         18.75
# 2                0.00                    1.0         31.30
# 3                0.00                    1.0         17.00
# 4                0.00                    1.0         16.10
# ...               ...                    ...           ...
# 2964619          0.00                    1.0         21.77
# 2964620          0.00                    1.0         25.74
# 2964621          0.00                    1.0         23.97
# 2964622          0.00                    1.0         33.46
# 2964623          6.94                    1.0         55.88
#
#          congestion_surcharge  Airport_fee
# 0                         2.5          0.0
# 1                         2.5          0.0
# 2                         2.5          0.0
# 3                         2.5          0.0
# 4                         2.5          0.0
# ...                       ...          ...
# 2964619                   NaN          NaN
# 2964620                   NaN          NaN
# 2964621                   NaN          NaN
# 2964622                   NaN          NaN
# 2964623                   NaN          NaN
#
# [2964624 rows x 19 columns]

# %%
#yellow_df = yellow_df[yellow_df['tpep_pickup_datetime'] < yellow_df['tpep_dropoff_datetime']]
yellow_df = yellow_df[(yellow_df['tpep_pickup_datetime'].dt.year == 2024) & (yellow_df['tpep_dropoff_datetime'].dt.year == 2024)]

# %%
yellow_df.shape
# Out:
# (2963739, 19)

# %%
yellow_df.loc[:,'trip_distance_km'] = round(yellow_df.loc[:,'trip_distance'] * 1.60934, 2)

# %%
yellow_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43                1
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36                1
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01                1
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56                1
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57                1
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36                0
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52                0
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00                0
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14                0
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30                0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.72           1                  N           186
# 1                 1.80           1                  N           140
# 2                 4.70           1                  N           236
# 3                 1.40           1                  N            79
# 4                 0.80           1                  N           211
# ...                ...         ...                ...           ...
# 2964619           3.18          99               None           107
# 2964620           4.00          99               None           114
# 2964621           3.33          99               None           211
# 2964622           3.06          99               None           107
# 2964623           8.10          99               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  79             2        17.70   1.00      0.5        0.00
# 1                 236             1        10.00   3.50      0.5        3.75
# 2                  79             1        23.30   3.50      0.5        3.00
# 3                 211             1        10.00   3.50      0.5        2.00
# 4                 148             1         7.90   3.50      0.5        3.20
# ...               ...           ...          ...    ...      ...         ...
# 2964619           263             0        15.77   0.00      0.5        2.00
# 2964620           236             0        18.40   1.00      0.5        2.34
# 2964621            25             0        19.97   0.00      0.5        0.00
# 2964622            13             0        23.88   0.00      0.5        5.58
# 2964623            75             0        32.40   7.75      0.5        7.29
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         22.70
# 1                0.00                    1.0         18.75
# 2                0.00                    1.0         31.30
# 3                0.00                    1.0         17.00
# 4                0.00                    1.0         16.10
# ...               ...                    ...           ...
# 2964619          0.00                    1.0         21.77
# 2964620          0.00                    1.0         25.74
# 2964621          0.00                    1.0         23.97
# 2964622          0.00                    1.0         33.46
# 2964623          6.94                    1.0         55.88
#
#          congestion_surcharge  Airport_fee  trip_distance_km
# 0                         2.5          0.0              2.77
# 1                         2.5          0.0              2.90
# 2                         2.5          0.0              7.56
# 3                         2.5          0.0              2.25
# 4                         2.5          0.0              1.29
# ...                       ...          ...               ...
# 2964619                   NaN          NaN              5.12
# 2964620                   NaN          NaN              6.44
# 2964621                   NaN          NaN              5.36
# 2964622                   NaN          NaN              4.92
# 2964623                   NaN          NaN             13.04
#
# [2963739 rows x 20 columns]

# %%
yellow_df['VendorID'].value_counts()
# Out:
# VendorID
# 2    2234514
# 1     729017
# 6        208
# Name: count, dtype: int64

# %%
yellow_df['passenger_count'].value_counts()
# Out:
# passenger_count
# 1    2188167
# 2     405025
# 0     171446
# 3      91246
# 4      51963
# 5      33501
# 6      22331
# 8         51
# 7          8
# 9          1
# Name: count, dtype: int64

# %%
another = yellow_df[yellow_df['passenger_count'].between(0, 6)]

# %%
another
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43                1
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36                1
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01                1
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56                1
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57                1
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36                0
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52                0
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00                0
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14                0
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30                0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.72           1                  N           186
# 1                 1.80           1                  N           140
# 2                 4.70           1                  N           236
# 3                 1.40           1                  N            79
# 4                 0.80           1                  N           211
# ...                ...         ...                ...           ...
# 2964619           3.18          99               None           107
# 2964620           4.00          99               None           114
# 2964621           3.33          99               None           211
# 2964622           3.06          99               None           107
# 2964623           8.10          99               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  79             2        17.70   1.00      0.5        0.00
# 1                 236             1        10.00   3.50      0.5        3.75
# 2                  79             1        23.30   3.50      0.5        3.00
# 3                 211             1        10.00   3.50      0.5        2.00
# 4                 148             1         7.90   3.50      0.5        3.20
# ...               ...           ...          ...    ...      ...         ...
# 2964619           263             0        15.77   0.00      0.5        2.00
# 2964620           236             0        18.40   1.00      0.5        2.34
# 2964621            25             0        19.97   0.00      0.5        0.00
# 2964622            13             0        23.88   0.00      0.5        5.58
# 2964623            75             0        32.40   7.75      0.5        7.29
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         22.70
# 1                0.00                    1.0         18.75
# 2                0.00                    1.0         31.30
# 3                0.00                    1.0         17.00
# 4                0.00                    1.0         16.10
# ...               ...                    ...           ...
# 2964619          0.00                    1.0         21.77
# 2964620          0.00                    1.0         25.74
# 2964621          0.00                    1.0         23.97
# 2964622          0.00                    1.0         33.46
# 2964623          6.94                    1.0         55.88
#
#          congestion_surcharge  Airport_fee  trip_distance_km
# 0                         2.5          0.0              2.77
# 1                         2.5          0.0              2.90
# 2                         2.5          0.0              7.56
# 3                         2.5          0.0              2.25
# 4                         2.5          0.0              1.29
# ...                       ...          ...               ...
# 2964619                   NaN          NaN              5.12
# 2964620                   NaN          NaN              6.44
# 2964621                   NaN          NaN              5.36
# 2964622                   NaN          NaN              4.92
# 2964623                   NaN          NaN             13.04
#
# [2963679 rows x 20 columns]

# %%
another['passenger_count'].value_counts()
# Out:
# passenger_count
# 1    2188167
# 2     405025
# 0     171446
# 3      91246
# 4      51963
# 5      33501
# 6      22331
# Name: count, dtype: int64

# %%
another
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43                1
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36                1
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01                1
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56                1
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57                1
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36                0
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52                0
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00                0
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14                0
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30                0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.72           1                  N           186
# 1                 1.80           1                  N           140
# 2                 4.70           1                  N           236
# 3                 1.40           1                  N            79
# 4                 0.80           1                  N           211
# ...                ...         ...                ...           ...
# 2964619           3.18          99               None           107
# 2964620           4.00          99               None           114
# 2964621           3.33          99               None           211
# 2964622           3.06          99               None           107
# 2964623           8.10          99               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  79             2        17.70   1.00      0.5        0.00
# 1                 236             1        10.00   3.50      0.5        3.75
# 2                  79             1        23.30   3.50      0.5        3.00
# 3                 211             1        10.00   3.50      0.5        2.00
# 4                 148             1         7.90   3.50      0.5        3.20
# ...               ...           ...          ...    ...      ...         ...
# 2964619           263             0        15.77   0.00      0.5        2.00
# 2964620           236             0        18.40   1.00      0.5        2.34
# 2964621            25             0        19.97   0.00      0.5        0.00
# 2964622            13             0        23.88   0.00      0.5        5.58
# 2964623            75             0        32.40   7.75      0.5        7.29
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         22.70
# 1                0.00                    1.0         18.75
# 2                0.00                    1.0         31.30
# 3                0.00                    1.0         17.00
# 4                0.00                    1.0         16.10
# ...               ...                    ...           ...
# 2964619          0.00                    1.0         21.77
# 2964620          0.00                    1.0         25.74
# 2964621          0.00                    1.0         23.97
# 2964622          0.00                    1.0         33.46
# 2964623          6.94                    1.0         55.88
#
#          congestion_surcharge  Airport_fee  trip_distance_km
# 0                         2.5          0.0              2.77
# 1                         2.5          0.0              2.90
# 2                         2.5          0.0              7.56
# 3                         2.5          0.0              2.25
# 4                         2.5          0.0              1.29
# ...                       ...          ...               ...
# 2964619                   NaN          NaN              5.12
# 2964620                   NaN          NaN              6.44
# 2964621                   NaN          NaN              5.36
# 2964622                   NaN          NaN              4.92
# 2964623                   NaN          NaN             13.04
#
# [2963679 rows x 20 columns]

# %%
another['store_and_fwd_flag'].value_counts()
# Out:
# store_and_fwd_flag
# N    2812569
# Y      11059
# Name: count, dtype: int64

# %%
another['payment_type'].value_counts()
# Out:
# payment_type
# 1    2318876
# 2     438555
# 0     140051
# 4      46626
# 3      19571
# Name: count, dtype: int64

# %%
another['VendorID'].value_counts()
# Out:
# VendorID
# 2    2234455
# 1     729016
# 6        208
# Name: count, dtype: int64

# %%
another['PULocationID'].value_counts()

# %%
another_cleaned = another[another['PULocationID'] < 264]

# %%
fee_cols = ['fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'total_amount', 'congestion_surcharge', 'Airport_fee', 'improvement_surcharge']

# %%
another_cleaned[fee_cols].min()

# %%
lookup_df

# %%
for i in range(len(fee_cols)):
    another_cleaned.loc[(another_cleaned[f'{fee_cols[i]}'] < 0) | (another_cleaned[f'{fee_cols[i]}'] is None), f'{fee_cols[i]}'] = 0

# %%
duplicates = lookup_df.groupby(['Zone', 'service_zone'])['Borough'].count().reset_index().rename(columns = {'Borough': 'count'}).sort_values(by = ['count'], ascending = False)

# %%
import networkx as nx

# %%
df_edges = another_cleaned[['PULocationID', 'DOLocationID']].dropna()

# %%
df_edges = df_edges.astype(int)

# %%
edge_list = df_edges.values.tolist()

# %%
G = nx.DiGraph()

# %%
G.add_edges_from(edge_list)

# %%
pagerank_scores = nx.pagerank(G, alpha = 0.85)

# %%
df_scores = pd.DataFrame.from_dict(
    pagerank_scores,
    orient = 'index',
    columns = ['pagerank_scores']
)

# %%
df_scores.index.name = 'LocationID'

# %%
df_results = lookup_df.merge(df_scores, on = 'LocationID')

# %%
df_results_sorted = df_results.sort_values(by = 'pagerank_scores', ascending = False)

# %%
df_results_sorted[['Zone', 'Borough', 'pagerank_scores']]

# %%
another_cleaned
